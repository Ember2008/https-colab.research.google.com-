# %% [markdown]
# <a href="https://colab.research.google.com/github/Ember2008/https-colab.research.google.com-/blob/main/week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np


students = ['preciouse','meline','linus','caleb','james','princess','jessical','john','joy','Hope','cypren','Abraham','rita','damian','David']
English_scores = [56,78,39,99,25,67,89,87,88,59,93,56,29,67,89]
maths_scores = [88,78,67,59,76,69,34,78,37,89,90,89,67,49,87]
physics_scores = [68,78,76,99,56,58,79,87,67,45,39,69,70,88,78]


plt.figure()
plt.hist(English_scores)
plt.title('Distribution of English_scores')
plt.xlabel('score Range')
plt.ylabel('Frequency')
plt.show()
# The following below is a graphical representation of Histogram.
 # the histogram below shows the English score distribution of numerical data.
 # the score range is at the x aixs while frequency is at the y axis of the histogram chart
 # At the y aixs from 0 we are using the defferece of 5 each
 # The English distribution scores Hist chart shows that we have more scores between 78-99
 # the Histogram chart shows that we have less range of scores between 55-70
 # it shows that the highest score comes from the range of 78-99 which is 99



plt.figure()
plt.scatter(English_scores,physics_scores)
plt.title('English_scores vs physics_scores')
plt.xlabel('English_scores')
plt.ylabel('physics_scores')
plt.show()
# the below chat shows scatter realationship between English and physics scores
# the English score is at the x axis while the physics scores are at the y axis
# the scatter chat maximun number it can represent for a given score at x,y axis is 100
# the scatter chat has much outliers
# the scatters chat is represented with dots


plt.figure()
plt.plot(students, maths_scores)
plt.plot(students, physics_scores)
plt.plot(students, English_scores)
plt.title('maths physics and English scores')
plt.xlabel('Students')
plt.ylabel('Scores')
#below is a line chart represented with trainz
# the students are at the x axis while the scores are at the y axis
# the line chart below is a relationship between maths,physics and english scores represented with defferent colour of trainz
# maths, physics and english are represented with blue,orang and green respectively.
# 99 is the highest score of two subjects physics and English and physics
# English has the highest and lowest score



plt.figure()
plt.subplot(1,2,1)
plt.hist(English_scores)
plt.title('Distribution of English_scores Histogram')
plt.subplot(1,2,2)
plt.scatter(English_scores,physics_scores)
plt.title('English_scores vs physics_scores')
plt.tight_layout()
plt.show()
#Below is a sublot that shows two different charts(histogram and scatter)
# the scatter the chart of both english and physics scores
# the histogram only shows the chart of english scores
# in the scatter chart the highest score of the bothe english and physics is 99 there fore the dot is one but note its representing the two subjects
# the highst score in thej histogram is 99 therefore it has a highest hist chart

# %% [markdown]
# NAME:Onyilo princess Theresa
# MATREIC NUMBER :UJ/2025/CP/376
# FACULTY:COMPUTING
# DEPARTMENT:DATA SCIENCE
